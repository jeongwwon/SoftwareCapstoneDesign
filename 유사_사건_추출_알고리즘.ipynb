# %%
import tarfile
import pandas as pd

file_name = 'filtered_dataset_df.tar.gz'

# 압축 풀기
with tarfile.open(file_name, 'r:gz') as tar:
    tar.extractall()

# CSV 파일을 DataFrame으로 불러오기
filtered_dataset_df = pd.read_csv('filtered_dataset_df.csv')
filtered_dataset_df
# Out:
#       판례정보일련번호                                                사건명  \
# 0        85843                                               독직상해
# 1        86117                                               상해치사
# 2        86203                                     공무상비밀표시무효,주거침입
# 3        86206                                     특수강도상해,특수강도미수등
# 4        86210                                               강도상해
# ...        ...                                                ...
# 4983    234647  근로에관한소송[구파견법에따라직접고용청구권을취득한파견근로자가사용사업주를상대로고용의사표...
# 4984    234695           부당이득금[파생상품거래에대해투자매매업자의착오로인한취소가능여부가문제된사건]
# 4985    234719                                            근로에관한소송
# 4986     73630              특정범죄가중처벌등에관한법률위반,허위공문서작성,동행사,직무유기피고사건
# 4987    197577                                        직무발명보상금청구의소
#
#               사건번호      선고일자   선고     법원명 사건종류명          판결유형  \
# 0         4285형비상1  19520422   선고     대법원    형사            판결
# 1        4288형상175  19550805   선고     대법원    형사            판결
# 2          4289형상5  19560305   선고     대법원    형사            판결
# 3        4289형상118  19560619   선고     대법원    형사            판결
# 4        4289형상170  19560817   선고     대법원    형사            판결
# ...            ...       ...  ...     ...   ...           ...
# 4983   2021다229601  20230427   선고     대법원    민사            판결
# 4984   2017다227264  20230427   선고     대법원    민사            판결
# 4985   2021다229588  20230427   선고     대법원    민사            판결
# 4986        74노328  19741230  NaN    서울고법    형사  제2형사부판결 : 확정
# 4987  2013나2016228  20140717   선고  서울고등법원    민사            판결
#
#                                                    판시사항  \
# 0                                              독직상해와 죄수
# 1                                          구금일수와 필요적 산입
# 2                                    피고인의 항소와 불이익변경의 금지
# 3                             형법 제57조와 형사소송법 제482조와의 관계
# 4        가. 절도죄와 재물의 악지 나. 타인의 혼수상태하에서 우발적으로 행한 도취죄의 태용
# ...                                                 ...
# 4983  [1] 사용사업주에 대한 회생절차개시결정이 있는 경우, 회생절차개시결정 전에 발생한...
# 4984  [1] 민법 제109조 제1항 단서에서 정한 ‘중대한 과실’의 의미 / 의사표시의 ...
# 4985  [1] 확인의 소에서 ‘확인의 이익’이 인정되기 위한 요건 [2] 사용사업주가 파견...
# 4986  작위범인 허위공문서작성죄만이 성립하고 따로 부작위범인 직무유기죄는 성립하지 않는다고...
# 4987                                                NaN
#
#                                                    판결요지  \
# 0     독직상해죄는 단순일죄이요 다만 그 처단에 있어서 형법 제10조에 의하여 이와 상해죄...
# 1     피고인의 공소를 파기함에 있어서 원심판결 선고전 구금일 수가 있으면 형법 제57조에...
# 2     제1심 판결이 2척의 공소범죄사실중 1척사실만을 인정하여 유죄를 선고하고 기여사실에...
# 3     형법 제57조에 의한 구금일수 통산은 형사소송법 제482조에 의하여 법정 통산을 할...
# 4     가. 설사 피해자가 졸도하여 의식을 상실한 경우에도 현장에 일실된 피해자의 물건은 ...
# ...                                                 ...
# 4983  [1] 구 파견근로자 보호 등에 관한 법률(2012. 2. 1. 법률 제11279호...
  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNDNTKBFXQ&Signature=d9N31l%2BIu7%2FDUD0q7uJ%2F%2BoKt2vI%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEFIaCXVzLWVhc3QtMSJGMEQCIB03U3m1ixhRl%2BdCxBLSYW111AObc38mf0XWakkzpFn1AiBs3zFhs2%2FW1jzoUGsWOgDLr3lWJ9u6jPHdRm4DiJiglSqwAgjq%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMOzuj%2Fu%2FoLsdUnKSnKoQCabk3nZfDFeAiC3ZWYlgzoyT3TJSZEKcVOR4xK29bzK%2FLxEv5rjJZMokvW6IUVk%2BWeCD8%2BWgk3nMItgfYk3F8p%2BXBju%2FofcWJOJv63%2BdnxPfXyLQGMceVjLbK4TP9AuOSDpSnzk9fdIIlvx66WeFwSE2o9Eu%2FMqAf2TYv%2BQ1SE5IvhTvU6MHv%2BXWbXP205JCeygmlWMjmffLgcGkv86S%2B7b%2BCcVs3s9UmY%2FL0WaeB30lnnVD2TBOfaNhegYmADk7psmNfrYtEhA94kpQCx1Szaghk%2FLtj%2F3ixERCIboVN9eRv8ivwO1E2otPIIJmET%2BobCcjeDATte5cirZF94bWllzshNkYw3fu%2FswY6ngFM5%2BIKOugKylvGV%2FfS9g1tr1%2Fq%2F8oeXNy9vJEiAgMG0pB2PAmcCjHuJzrQxTuYZEEj1GcY7QetSQprDULKItGRB7GeYq8OgmDFOJHueK77Od01109hYUS5aMaAZgdvUhNQ%2B1A3IrgzXBO%2FnF3vt%2BBindP8c2bjL2O0m%2FfiQniyJuhYkcC8ZWtSmtPysX0SxOFgScaL2k%2Br3XYZSLMl5w%3D%3D&Expires=1718617317
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.136.193, 52.217.126.1, 52.217.135.33, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.136.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  63.7MB/s    in 0.7s
#
# 2024-06-17 09:14:24 (63.7 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/v0.6.0/scripts/mecab.sh)
# https://github.com/konlpy/konlpy/issues/395#issue-1099168405 - 2022.01.11
# Done
# Install mecab-python
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.
# light 버전 작성 : Dogdriip님 ( https://github.com/Dogdriip )
# 문제를 해결해주신 combacsa님 감사합니다.

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 56.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import requests
from bs4 import BeautifulSoup
import re
from konlpy.tag import Mecab

# 뉴스 기사 URL
url = 'https://n.news.naver.com/mnews/article/659/0000022518'
mecab = Mecab()
# 웹 페이지 가져오기
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# id가 'newsct_article'인 div 요소 추출
article_title = soup.find('h2', {'id': 'title_area'})
span_text = article_title.find('span').text

article = soup.find('div', {'id': 'newsct_article'})

# 'article'이 제대로 추출되었는지 확인
if article is None:
    print("기사 내용을 찾을 수 없습니다.")
else:
    # 기사 본문 텍스트 추출
    article_text = article.get_text(separator='\n', strip=True)
    # 혐의가 들어간 문장 추출
    sentences = article_text.split('.')

# %%
def extract_sentence_length(sentence):
    """주어진 문장에서 '징역' 형량을 개월 단위로 추출하여 변환합니다. 집행유예도 함께 추출합니다."""
    result = {}

    # '무기징역' 처리
    if '무기징역' in sentence:
        result['징역'] = '무기징역'
        return result

    # '징역' 형량 처리
    match = re.search(r'징역\s*(\d+)\s*년\s*(\d+)?\s*(월|개월)?', sentence)
    if match:
        years = int(match.group(1)) if match.group(1) else 0
        months = int(match.group(2)) if match.group(2) else 0
        result['징역'] = years * 12 + months

    else:  # 별도의 경우를 위한 매치
        match = re.search(r'징역\s*(\d+)\s*(월|개월)', sentence)
        if match:
            result['징역'] = int(match.group(1))

        match = re.search(r'징역\s*(\d+)\s*년', sentence)
        if match:
            result['징역'] = int(match.group(1)) * 12

    # '집행유예' 처리
    match = re.search(r'집행유예\s*(\d+)\s*년\s*(\d+)?\s*(월|개월)?', sentence)
    if match:
        years = int(match.group(1)) if match.group(1) else 0
        months = int(match.group(2)) if match.group(2) else 0
        result['집행유예'] = years * 12 + months

    else:  # 별도의 경우를 위한 매치
        match = re.search(r'집행유예\s*(\d+)\s*(월|개월)', sentence)
        if match:
            result['집행유예'] = int(match.group(1))

        match = re.search(r'집행유예\s*(\d+)\s*년', sentence)
        if match:
            result['집행유예'] = int(match.group(1)) * 12

    if result:
        return result
    else:
        return None

# %%
# 판결 유무 저장
judge=True
# 정규 표현식을 사용하여 '징역' 단어 검색
if re.search(r'징역',article_text):
    for sentence in sentences:
        newsart = extract_sentence_length(sentence)
        if newsart:  # 징역 관련 정보가 추출되면 종료
            break
else:
    judge = False
    newsart = None

if isinstance(newsart, dict):
    if '징역' in newsart:
        newsjail = newsart['징역']
    if '집행유예' in newsart:
        newspro = newsart['집행유예']

# %%
article_text
# Out:
# '[전주MBC 자료사진]\n한동훈 전 법무부 장관의 명예를 훼손한 혐의로 재판에 넘겨진 유시민 전 노무현재단 이사장의 벌금형이 확정됐습니다.\n오늘(17일) 대법원 3부(주심 노정희 대법관)는 라디오에 의한 명예훼손 혐의에 대한 유 전 이사장의 상고심에서 상고를 기각하고 벌금형을 확정했습니다.\n유 전 이사장은 지난 2019년 12월, 2020년 4월과 10월 유튜브와 라디오 시사프로그램 등에서 당시 대검찰청 반부패강력부장이던 한동훈 전 장관이 자신의 계좌를 사찰했다는 의혹을 제기했습니다.\n이에 한 전 장관은 "허위 사실"이라며 유 전 이사장을 고소했습니다.\n유 전 이사장은 1심과 2심에서 벌금 500만 원을 선고받았습니다.\n이와 별개로 한 전 장관은 유 전 이시장을 상대로 5억 원 상당의 손해배상 청구 소송도 제기했습니다.'

# %%
# 벌금 관련 정보 추출
fine_pattern = re.compile(r'(\d{1,3}(?:,\d{3})*)\s*만?\s*원\s*벌금')
fine_matches = fine_pattern.findall(article_text)

if fine_matches:
    fines = []
    for match in fine_matches:
        # 숫자 추출 및 변환 (예: '500만' -> 5000000, '1,000' -> 1000)
        fine_amount = int(match.replace(',', ''))
        if '만' in match:
            fine_amount *= 10000
        if fine_amount >= 500000:
            fines.append(fine_amount)
    if fines:
        newsart = f"벌금 {', '.join(map(str, fines))}원"
        judge = True

# 출력 결과
print(f"judge: {judge}, newsart: {newsart}")
# Out:
# judge: False, newsart: None

# %%
print(f"judge: {judge}, newsart: {newsart}")
# Out:
# judge: False, newsart: None

# %%
cd ..
# Out:
# /

# %%
cd content
# Out:
# /content

# %%
import tarfile
import joblib

# tar 파일 해제
tar_filename = 'models.tar.gz'
with tarfile.open(tar_filename, 'r:gz') as tar:
    tar.extractall()

# TF-IDF 벡터 로드
tfidf_vectorizer = joblib.load('tfidf_vectorizer.pkl')

# SVM 모델 로드
svm_model = joblib.load('svm_model.joblib')

# %%
# 문장을 벡터로 변환
vectorized_sentence = tfidf_vectorizer.transform([span_text])

# 예측 수행
prediction = svm_model.predict(vectorized_sentence)

print(f"예측된 범죄 유형: {prediction[0]}")
# Out:
# 예측된 범죄 유형: 명예

# %% [markdown]
# # 혐의를 나타내는 대표 문장 추출

# %%
        charges = []
        charges2=[]
        tvalue=0
        tindex=[]
        reall=[]
        for sentence in sentences:
            if '혐의' in sentence:
                real=""
                charges2.append(sentence)
                sentence = sentence.strip()
                혐의_idx = sentence.find('혐의')

                if len(sentence) > 혐의_idx + 1 and sentence[혐의_idx + 2] == '(':
                  start = sentence.find('(', 혐의_idx)
                  end = sentence.find(')', start)
                  real=sentence[start+1:end].strip()
                  reall.append(real)


                if re.search(r'(에게|[은는이가])', sentence):
                    end_idx = sentence.index('혐의')
                    if real:
                      charges.append(sentence[:end_idx] + ' ' + real)
                      real=False
                    else:
                      charges.append(sentence[:end_idx])

         # 혐의가 들어간 문장에서 '혐의'가 나오기 전 문장으로 추출
        charges_before = []
        original_sentences = []
        for sentence in charges:

            tvalue+=1
            words = re.split(r'\s+', sentence)
            extract = False
            extracted_sentence = ""
            last_josa_idx = -1

            # '은/는/이/가/에게'의 마지막 위치를 찾음
            for i, word in enumerate(words):
                if re.search(r'(은|는|이|가|에게)$', word):
                    last_josa_idx = i

            # 마지막 조사 이후부터 '혐의'가 나오기 전까지 추출
            if last_josa_idx != -1:
                for word in words[last_josa_idx + 1:]:
                    extracted_sentence += word + " "
                    if '혐의' in word:
                        extracted_sentence = extracted_sentence.replace('혐의', '')
                        break
            else:
                for word in words:
                    extracted_sentence += word + " "
                    if '혐의' in word:
                        extracted_sentence = extracted_sentence.replace('혐의', '')
                        break
            if extracted_sentence:
                tindex.append(tvalue-1)
                charges_before.append(extracted_sentence)
                original_sentences.append(sentence)

# %%
charges
# Out:
# ['울산지법 형사11부(이대로 부장판사)는 자신보다 10살 정도 어린 처음 본 사람에게 반말로 말을 걸었다가 항의를 듣자 화가 나 흉기로 살해하려 한  살인미수']

# %%
charges_before
# Out:
# ['나 흉기로 살해하려 한 살인미수 ']

# %%
        corrected_charges_before = []
        for original, extracted in zip(original_sentences, charges_before):
            start_idx = original.find(extracted[:2])  # charges_before의 처음 두 글자 찾기
            if start_idx != -1:
                corrected_sentence = original[start_idx:]  # 일치하는 위치에서부터 자르기
                corrected_charges_before.append(corrected_sentence.strip())
            else:
                corrected_charges_before.append(extracted.strip())
        corrected_charges_before = [sentence.replace(",", " ") for sentence in corrected_charges_before]

# %%
if prediction[0]=='뇌물수수':
  prediction[0]='횡령'
# 해당 키워드가 들어간 사건명을 검색하고 key값 저장
keywords = {
    "살인":{"살인"},
    "절도":{"절도","불법사용","침입절도"},
    "장물":{"장물"},
    "사기":{"사기","컴퓨터등사용사기","부당이득","편의시설부정이용","전기통신금융사기","보험사기"},
    "횡령":{"횡령"},
    "배임":{"배임"},
    "도로교통법":{"운전","도로","도주치상","위험운전치상"},
    "손괴":{"손괴"},
    "강도":{"강도"},
    "방화":{"방화"},
    "성폭력":{"성폭력","강간","특수강도강간","카메라등이용촬영","공중밀집에서의추행","음란물"},
    "폭행":{"폭행","폭력행위"},
    "상해":{"상해"},
    "협박":{"협박"},
    "공갈":{"공갈"},
    "약취/유인":{"약취","유인","부녀매매","국외이송"},
    "체포/감금":{"체포","감금"},
    "위조범죄":{"통화","유가","인지","우표","문서","인장"},
    "공무원범죄":{"직무","직권","수뢰","증뢰"},
    "도박":{"도박","복표"},
    "과실범죄":{"과실","실화"},
    "명예":{"명예"},
    "권리행사방해":{"권리행사방해"},
    "주거침입":{"주거침입"},
    "비밀침해":{"비밀침해"},
    "유기":{"유기"},
    "교통방해":{"교통방해"},
    "도주/범죄은닉":{"도주","은닉"},
    "위증과증거인멸":{"위증","증거인멸"},
    "무고":{"무고"},
    "가정폭력":{"가정폭력"},
    "개인정보보호법":{"개인정보"},
    "건설":{"건설","건축"},
    "게임산업진흥법":{"게임"},
    "고용보험법":{"고용보험"},
    "공유수면관리":{"공유수면"},
    "공인중개사법":{"공인중개"},
    "공중위생법":{"공중위생"},
    "공직선거법":{"공직선거"},
    "관세법":{"관세"},
    "교통사고처리특례법":{"교통사고"},
    "국가기술자격법":{"국가기술자격"},
    "국가보안법":{"국가보안"},
    "국민체육진흥법":{"국민체육"},
    "근로기준법":{"근로","퇴직","급여"},
    "노동조합":{"노동"},
    "농수산물":{"농수산물"},
    "도시및주거환경":{"도시","주거환경"},
    "공정거래법":{"독점","공정거래"},
    "마약류관리에관한법률":{"마약"},
    "변호사법":{"변호사"},
    "병역법":{"병역"},
    "부동산":{"부동산"},
    "부정경쟁방지및영업비밀보호":{"부정경쟁","영업비밀"},
    "부정수표":{"부정수표"},
    "사해행위":{"사해행위"},
    "산업안전보건법":{"산업안전"},
    "산지관리법":{"산지"},
    "상표법":{"상표"},
    "선박":{"선박"},
    "성매매알선":{"성매매"},
    "식품위생법":{"식품위생"},
    "아동˙청소년":{"아동·청소년의성보호","아동"},
    "약사법":{"약사법"},
    "외국환거래법":{"외국환"},
    "의료법":{"의료"},
    "자동차":{"자동차"},
    "자본시장과금융투자업":{"자본시장","금융투자"},
    "저작권법":{"저작권"},
    "전자금융거래법":{"전자금융"},
    "정보통신망":{"정보통신망"},
    "조세범처벌법":{"조세범"},
    "주민등록법":{"주민등록법"},
    "주택법":{"주택"},
    "집회및시위":{"집회","시위"},
    "총포·도검·화약류단속":{"총포","도검","화약류"},
    "특허법":{"특허"},
    "폐기물관리법":{"폐기물"}
}

# %%
corrected_charges_before
# Out:
# ['[전주MBC 자료사진]\n한동훈 전 법무부 장관의 명예를 훼손한', '라디오에 의한 명예훼손']

# %%
        split_sentences = []
        for sentence in corrected_charges_before:
            words = re.split(r'[ ,\(\)·]', sentence)
            split_sentences.append([word for word in words if word])

# %%
split_sentences
# Out:
# [['나', '흉기로', '살해하려', '한', '살인미수']]

# %%
matche = []
for lis in split_sentences:
    a = 0
    for words in lis:
        for words2 in keywords[prediction[0]]:
            if words==words2:
              a += 1
    matche.append(a)
max_match_index=matche.index(max(matche))

# %%
corrected_sentence = charges2[max_match_index].replace('\n','')
corrected_sentence
# Out:
# '[전주MBC 자료사진]한동훈 전 법무부 장관의 명예를 훼손한 혐의로 재판에 넘겨진 유시민 전 노무현재단 이사장의 벌금형이 확정됐습니다'

# %% [markdown]
# # 추출된 대표 문장에서 혐의 추출

# %%
import re

def extract_text_after_first_josa(text):
    mecab = Mecab()
    tokens = mecab.pos(text)
    print("Tokens:", tokens)

    # 모든 조사 위치를 저장
    josa_indices = [i for i, token in enumerate(tokens) if 'J' in token[1]]
    print("Josa indices:", josa_indices)

    if josa_indices:
        first_josa_idx = josa_indices[0]
        first_josa_token = tokens[first_josa_idx][0]

        # 원래 텍스트에서 첫 번째 조사의 실제 위치 찾기
        cumulative_length = 0
        first_josa_position = -1

        for i, (token, pos) in enumerate(tokens):
            # 현재 형태소의 시작 위치를 찾기
            token_position = text[cumulative_length:].find(token) + cumulative_length

            if i == first_josa_idx:
                first_josa_position = token_position
                break

            cumulative_length = token_position + len(token)

        if first_josa_position != -1:
            start_idx = first_josa_position + len(first_josa_token)

            # "혐의"의 위치를 찾음, start_idx 이후부터 검색
            혐의_idx = text.find('혐의', start_idx)
            real = ""

            # "혐의" 이후에 괄호가 있는지 확인
            if 혐의_idx != -1 and len(text) > 혐의_idx + 1 and text[혐의_idx + 1] == '(':
                start = text.find('(', 혐의_idx)
                end = text.find(')', start)
                if end != -1:
                    real = text[start + 1:end].strip()

            if 혐의_idx != -1:
                end_idx = 혐의_idx
            else:
                end_idx = len(text)  # "혐의"가 없으면 텍스트의 끝까지 추출

            if real:
                extracted_text = text[start_idx:end_idx].strip() + ' ' + real
            else:
                extracted_text = text[start_idx:end_idx].strip()
            return extracted_text

    return ""

# %%
corrected_sentence
# Out:
# '[전주MBC 자료사진]한동훈 전 법무부 장관의 명예를 훼손한 혐의로 재판에 넘겨진 유시민 전 노무현재단 이사장의 벌금형이 확정됐습니다'

# %%
correct_charge = extract_text_after_first_josa(corrected_sentence)
if reall:
  correct_charge=reall[0]
print(correct_charge)
# Out:
# Tokens: [('[', 'SSO'), ('전주', 'NNP'), ('MBC', 'SL'), ('자료', 'NNG'), ('사진', 'NNG'), (']', 'SSC'), ('한동훈', 'NNP'), ('전', 'MM'), ('법무부', 'NNG'), ('장관', 'NNG'), ('의', 'JKG'), ('명예', 'NNG'), ('를', 'JKO'), ('훼손', 'NNG'), ('한', 'XSV+ETM'), ('혐의', 'NNG'), ('로', 'JKB'), ('재판', 'NNG'), ('에', 'JKB'), ('넘겨진', 'VV+EC+VX+ETM'), ('유시민', 'NNP'), ('전', 'NNP'), ('노무현', 'NNP'), ('재단', 'NNG'), ('이', 'JKS'), ('사장', 'NNG'), ('의', 'JKG'), ('벌금형', 'NNG'), ('이', 'JKS'), ('확정', 'NNG'), ('됐', 'XSV+EP'), ('습니다', 'EF')]
# Josa indices: [10, 12, 16, 18, 24, 26, 28]
# 명예를 훼손한

# %%
def extract_text_without_josa(word):
    tokens = mecab.pos(word)

    # Filter out postpositions (조사)
    filtered_tokens = [token for token, pos in tokens if 'J' not in pos]
    filtered_text = ''.join([token for token in filtered_tokens])

    return filtered_text

# %%
import pandas as pd

# 주어진 텍스트
charges_before = correct_charge
# 쉼표 단위로 분리하여 리스트 만듦
phrases = charges_before.split(',')
print(phrases)
# 결과를 저장할 리스트
results = []
a=0
for phrase in phrases:
    if "(" in phrase and ")" in phrase:
      start = phrase.find('(') + 1
      end = phrase.find(')')
      phrase2=phrase[start:end]
      results.append(phrase2)
      a+=1
    # 단어들을 공백을 기준으로 분리하여 리스트로 만듦
    words = [word.strip() for word in phrase.split() if word.strip()]
    conv = ""
    for i, word in enumerate(words):
        word = extract_text_without_josa(word)
    # Exclude the word if it is a postposition (조사)
        if "("in word:
          results.append(conv)
          break
        origin=conv
        conv += word
        if filtered_dataset_df['사건명'].str.contains(conv).any():
          if i== len(words)-1:
            results.append(conv)
            conv=""
            break
          continue
        #포함이 되어있지 않고 리스트의 끝이 아니라면
        else :
            if not origin:
              conv=""
              continue
            results.append(origin)  # 이전 단어까지 추가
            conv=""
            break

print("결과 리스트:", results)
# Out:
# ['명예를 훼손한']
# 결과 리스트: ['명예']

# %%
filtered_cases = filtered_dataset_df[filtered_dataset_df['분류'] == prediction[0]]

# '사건명'이 results 리스트의 단어를 포함하는지 확인하고, '사건개수'가 len(results)보다 작거나 같은 행 필터링
len_results = len(results)
final_filtered_cases = filtered_dataset_df[
    filtered_dataset_df['사건명'].apply(lambda x: all(word in x for word in results)) &
    (filtered_dataset_df['사건개수'] <= len_results)
]

# %%
matching_cases=final_filtered_cases

# %%
matching_cases
# Out:
#       판례정보일련번호                                   사건명         사건번호      선고일자  \
# 1013    227585                            출판물에의한명예훼손      93노1025  19931202
# 1028    110146                            출판물에의한명예훼손      93도3535  19940412
# 1090    129674                                 명예퇴직금     96나21289  19970122
# 1142    120859                               명예희망퇴직금    98가합92875  19990610
# 1303    228043                                 명예퇴직금  2005가합50541  20051124
# 1705     64660          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)   2007고정2015  20071010
# 1725     70939                           명예훼손에따른손해배상   2007가합2569  20071114
# 1842     64520          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2007노1698  20080514
# 1919    127674                        모욕(택일적죄명:명예훼손)    2008노1724  20080919
# 1923     64693          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2008도4740  20080925
# 1978    125029                        모욕(택일적죄명:명예훼손)    2008도8917  20081211
# 2086    152125                                  명예훼손   2008고정4334  20090416
# 2163    152114                                  명예훼손    2009노1249  20090626
# 2261    147527          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2009노1510  20091022
# 2590    147199          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)   2009도12132  20101125
# 3027    167960          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2012고단710  20120607
# 1919  원심판결을 파기한다.\n피고인을 벌금 500,000원에 처한다.\n피고인이 위 벌금...    NaN       NaN
# 1923                원심판결을 파기하고, 사건을 서울남부지방법원 합의부로 환송한다.    NaN       NaN
# 1978               원심판결을 파기하고, 사건을 광주지방법원 본원 합의부에 환송한다.    NaN       NaN
# 2086  피고인을 벌금 500,000원에 처한다.\n피고인이 위 벌금을 납입하지 아니하는 경...    NaN       NaN
# 2163                                     피고인의 항소를 기각한다.    NaN       NaN
# 2261  원심판결을 파기한다.\n피고인을 벌금 300만 원에 처한다.\n피고인이 위 벌금을 ...    NaN       NaN
# 2590              원심판결을 파기하고, 사건을 의정부지방법원 본원 합의부에 환송한다.    NaN       NaN
# 3027  피고인을 벌금 500,000원에 처한다.\n피고인이 위 벌금을 납입하지 아니하는 경...    NaN       NaN
# 3070                                     피고인의 항소를 기각한다.    NaN       NaN
# 4252                      상고를 모두 기각한다. 상고비용은 피고들이 부담한다.    NaN       NaN
# 4695                                          상고를 기각한다.    NaN       NaN
#
#               벌금  사건개수
# 1013         NaN     1
# 1028         NaN     1
# 1090  48000000.0     1
# 1142   5685807.0     1
# 1303  63990000.0     1
# 1705   2500000.0     1
# 1725   7000000.0     1
# 1842   2500000.0     1
# 1919    500000.0     1
# 1923   2500000.0     1
# 1978    500000.0     1
# 2086    500000.0     1
# 2163    500000.0     1
# 2261   3000000.0     1
# 2590   3000000.0     1
# 3027    500000.0     1
# 3070    500000.0     1
# 4252   3000000.0     1
# 4695   1000000.0     1

# %%
def convert_sentence_to_numeric(value):
            if value == '무기징역':
                return -1
            elif value == '사형':
                return -2
            elif value == 'None' or value == 'NaN':
                return 0
            else:
                return pd.to_numeric(value, errors='coerce')

# %%
        import numpy as np

        matching_cases['징역(개월)'] = matching_cases['징역(개월)'].apply(convert_sentence_to_numeric).fillna(0)
        matching_cases['집행유예(개월)'] = matching_cases['집행유예(개월)'].apply(convert_sentence_to_numeric).fillna(0)
        matching_cases['벌금'] = matching_cases['벌금'].fillna(0)

        matching_cases2 = matching_cases[(matching_cases['징역(개월)'] == 0) &
                                 (matching_cases['집행유예(개월)'] == 0) &
                                 (matching_cases['벌금'] == 0)]

        matching_cases = matching_cases[~((matching_cases['징역(개월)'] == 0) & (matching_cases['집행유예(개월)'] == 0) & (matching_cases['벌금'] == 0))]

        # 판결 유형 존재 여부 열 추가
        matching_cases['징역'] = matching_cases['징역(개월)'].apply(lambda x: 1 if float(x) > 0 else 0)
        matching_cases['집행유예'] = matching_cases['집행유예(개월)'].apply(lambda x: 1 if float(x) > 0 else 0)
        matching_cases['벌금1'] =matching_cases['벌금'].apply(lambda x: 1 if float(x) > 0 else 0)

        #total은 유사 판례수
        total=len(matching_cases)
        # 판결 유형별 빈도 계산
        matching_cases['징역(년)'] = matching_cases['징역(개월)'] / 12
        jail_count = matching_cases['징역'].sum()
        probation_count = matching_cases['집행유예'].sum()
        fine_count = matching_cases['벌금1'].sum()
        total_count = jail_count + probation_count + fine_count
        # 백분율 계산
        jail_percentage = (jail_count / total_count) * 100
        probation_percentage = (probation_count / total_count) * 100
        fine_percentage = (fine_count / total_count) * 100
# Out:
# <ipython-input-271-6af2cd589aaf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_cases['징역(개월)'] = matching_cases['징역(개월)'].apply(convert_sentence_to_numeric).fillna(0)
# <ipython-input-271-6af2cd589aaf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_cases['집행유예(개월)'] = matching_cases['집행유예(개월)'].apply(convert_sentence_to_numeric).fillna(0)
# <ipython-input-271-6af2cd589aaf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_cases['벌금'] = matching_cases['벌금'].fillna(0)

# %%
matching_cases
# Out:
#       판례정보일련번호                                   사건명         사건번호      선고일자  \
# 1013    227585                            출판물에의한명예훼손      93노1025  19931202
# 1028    110146                            출판물에의한명예훼손      93도3535  19940412
# 1090    129674                                 명예퇴직금     96나21289  19970122
# 1142    120859                               명예희망퇴직금    98가합92875  19990610
# 1303    228043                                 명예퇴직금  2005가합50541  20051124
# 1705     64660          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)   2007고정2015  20071010
# 1725     70939                           명예훼손에따른손해배상   2007가합2569  20071114
# 1842     64520          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2007노1698  20080514
# 1919    127674                        모욕(택일적죄명:명예훼손)    2008노1724  20080919
# 1923     64693          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2008도4740  20080925
# 1978    125029                        모욕(택일적죄명:명예훼손)    2008도8917  20081211
# 2086    152125                                  명예훼손   2008고정4334  20090416
# 2163    152114                                  명예훼손    2009노1249  20090626
# 2261    147527          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2009노1510  20091022
# 2590    147199          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)   2009도12132  20101125
# 3027    167960          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)    2012고단710  20120607
# 3070    167945          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)     2012노729  20120809
# 4252    194926  손해배상(기)등(신문기사로인한명예훼손에따른불법행위책임을인정한사건)   2015다45857  20180412
# 4695    212817          정보통신망이용촉진및정보보호등에관한법률위반(명예훼손)   2020도11471  20201210
#
#       선고       법원명 사건종류명        판결유형  \
# 1013  선고      서울지법    형사  제6부판결 : 상고
# 1028  선고       대법원    형사          판결
# 1090  선고      서울고법    민사       판결：확정
# 1142  선고      서울지법    민사       판결：항소
# 1303  선고    서울중앙지법    민사     판결 : 확정
# 1705  선고  서울남부지방법원    형사          판결
# 1725  선고      대구지법    민사     판결 : 확정
# 1842  선고  서울남부지방법원    형사          판결
# 1919  선고    광주지방법원    형사          판결
# 1923  선고       대법원    형사          판결
# 1978  선고       대법원    형사          판결
# 2086  선고    인천지방법원    형사          판결
# 2163  선고    인천지방법원    형사          판결
# 2261  선고   의정부지방법원    형사          판결
# 2590  선고       대법원    형사          판결
# 3027  선고  서울북부지방법원    형사          판결
# 3070  선고  서울북부지방법원    형사          판결
# 4252  선고       대법원    민사          판결
# 4695  선고       대법원    형사          판결
#
#                                                    판시사항  \
# 1013  가. 타인을 비방할 목적으로 허위사실인 기사의 재료를 신문기자에게 제공하여 신문지상...
# 1028  가. 신문기자에게 기사재료를 제공한 자에게 출판물에 의한 명예훼손죄의책임이 인정되는...
# 1090  [1] 단체협약에 "명예퇴직을 신청하는 경우에는 명예퇴직을 할 수 있다."라고 규정...
# 1142  [1] 명예희망퇴직 대상자 지정에 따라 명예희망퇴직 신청을 한 후 퇴직일까지 약 3...
# 1303  [1] 근로자의 명예퇴직 신청에 대한 사용자의 심사·결정 권한 행사의 범위 [2] ...
# 1705                                                NaN
# 1725  [1] 법원이 종교단체의 권징재판에 따른 징계의 효력 유무나 그 당부를 판단할 수 ...
# 1842                                                NaN
# 1919                                                NaN
# 1923  [1] 정보통신망 이용촉진 및 정보보호 등에 관한 법률 제61조에 정한 ‘사람을 비...
# 1978  [1] 모욕죄에서 말하는 ‘모욕’의 의미 [2] 임대아파트의 분양전환과 관련하여 임...
# 2086                                                NaN
# 2163                                                NaN
# 2261                                                NaN
# 2590  [1] 구 정보통신망 이용촉진 및 정보보호 등에 관한 법률 제70조 제2항의 허위사...
# 3027                                                NaN
# 3070                                                NaN
# 4252  [1] 민법상 불법행위가 되는 명예훼손의 의미 및 명예훼손에서 ‘사실의 적시’가 있...
# 4695  정보통신망 이용촉진 및 정보보호 등에 관한 법률 제70조 제2항 명예훼손죄의 구성요...
#
#                                                    판결요지  ...  분류  \
# 1013  가. 타인을 비방할 목적으로 허위사실인 기사의 재료를 신문기자에게 제공한 경우 이 ...  ...  명예
# 1028  가. 타인을 비방할 목적으로 허위사실인 기사의 재료를 신문기자에게 제공한 경우에 기...  ...  명예
# 1090  [1] 단체협약에 "명예퇴직을 신청하는 경우에는 명예퇴직을 할 수 있다."라고 규정...  ...  명예
# 1142  [1] 명예희망퇴직 대상자 지정에 따라 명예희망퇴직 신청을 한 후 퇴직일까지 약 3...  ...  명예
# 1303  [1] 회사의 취업규칙 등에서 명예퇴직 신청자격이 있는 근로자의 신청만으로 명예퇴직...  ...  명예
# 1705                                                NaN  ...  명예
# 1725  [1] 종교단체의 권징재판은 일반 국민의 권리의무나 법률관계를 규율하는 것이 아니라...  ...  명예
# 1842                                                NaN  ...  명예
# 1919                                                NaN  ...  명예
# 1923  [1] 정보통신망 이용촉진 및 정보보호 등에 관한 법률 제61조에 규정된 ‘사람을 ...  ...  명예
# 1978  [1] 모욕죄에서 말하는 ‘모욕’이란 사실을 적시하지 아니하고 사람의 사회적 평가를...  ...  명예
# 2086                                                NaN  ...  명예
# 2163                                                NaN  ...  명예
# 2261                                                NaN  ...  명예
# 2590  [1] 형사재판에서 공소가 제기된 범죄의 구성요건을 이루는 사실은 그것이 주관적 요...  ...  명예
# 3027                                                NaN  ...  명예
# 3070                                                NaN  ...  명예
# 4252  [1] 민법상 불법행위가 되는 명예훼손이란 사람의 품성, 덕행, 명성, 신용 등 인...  ...  명예
# 4695  정보통신망 이용촉진 및 정보보호 등에 관한 법률 제70조 제2항은 “사람을 비방할 ...  ...  명예
#
#                                                      판결 징역(개월) 집행유예(개월)  \
# 1013  원심판결을 파기한다.\n피고인을 징역 8월에 처한다.\n다만 이 판결이 확정되는 날...    8.0     12.0
# 1028                                          상고를 기각한다.    8.0     12.0
# 1090  1. 원고들의 항소를 기각한다.\n2. 항소비용은 원고들의 부담으로 한다.\n【청구...    0.0      0.0
# 1142  1. 원고(반소피고)의 본소청구를 기각한다.\n2. 원고(반소피고)는 피고(반소원고...    0.0      0.0
# 1303  1. 원고의 청구를 기각한다.\n2. 소송비용은 원고가 부담한다.\n【청구취지】\n...    0.0      0.0
# 1705  피고인을 벌금 250만 원에 처한다.\n피고인이 위 벌금을 납입하지 아니하는 경우 ...    0.0      0.0
# 1725  1. 원고의 피고들에 대한 청구를 모두 기각한다.\n2. 소송비용은 원고가 부담한다...    0.0      0.0
# 1842  원심판결을 파기한다.\n피고인을 벌금 2,500,000원에 처한다.\n피고인이 위 ...    0.0      0.0
# 1919  원심판결을 파기한다.\n피고인을 벌금 500,000원에 처한다.\n피고인이 위 벌금...    0.0      0.0
# 1923                원심판결을 파기하고, 사건을 서울남부지방법원 합의부로 환송한다.    0.0      0.0
# 1978               원심판결을 파기하고, 사건을 광주지방법원 본원 합의부에 환송한다.    0.0      0.0
# 2086  피고인을 벌금 500,000원에 처한다.\n피고인이 위 벌금을 납입하지 아니하는 경...    0.0      0.0
# 2163                                     피고인의 항소를 기각한다.    0.0      0.0
# 2261  원심판결을 파기한다.\n피고인을 벌금 300만 원에 처한다.\n피고인이 위 벌금을 ...    0.0      0.0
# 2590              원심판결을 파기하고, 사건을 의정부지방법원 본원 합의부에 환송한다.    0.0      0.0
# 3027  피고인을 벌금 500,000원에 처한다.\n피고인이 위 벌금을 납입하지 아니하는 경...    0.0      0.0
# 3070                                     피고인의 항소를 기각한다.    0.0      0.0
# 4252                      상고를 모두 기각한다. 상고비용은 피고들이 부담한다.    0.0      0.0
# 4695                                          상고를 기각한다.    0.0      0.0
#
#               벌금  사건개수  징역  집행유예  벌금1     징역(년)
# 1013         0.0     1   1     1    0  0.666667
# 1028         0.0     1   1     1    0  0.666667
# 1090  48000000.0     1   0     0    1  0.000000
# 1142   5685807.0     1   0     0    1  0.000000
# 1303  63990000.0     1   0     0    1  0.000000
# 1705   2500000.0     1   0     0    1  0.000000
# 1725   7000000.0     1   0     0    1  0.000000
# 1842   2500000.0     1   0     0    1  0.000000
# 1919    500000.0     1   0     0    1  0.000000
# 1923   2500000.0     1   0     0    1  0.000000
# 1978    500000.0     1   0     0    1  0.000000
# 2086    500000.0     1   0     0    1  0.000000
# 2163    500000.0     1   0     0    1  0.000000
# 2261   3000000.0     1   0     0    1  0.000000
# 2590   3000000.0     1   0     0    1  0.000000
# 3027    500000.0     1   0     0    1  0.000000
# 3070    500000.0     1   0     0    1  0.000000
# 4252   3000000.0     1   0     0    1  0.000000
# 4695   1000000.0     1   0     0    1  0.000000
#
# [19 rows x 23 columns]

# %%
percentages = {
    '징역': jail_percentage,
    '집행유예': probation_percentage,
    '벌금': fine_percentage
}
highest_percentage = max(percentages, key=percentages.get)

# 가장 높은 percentage에 따른 로직 수행
if highest_percentage == '징역':
    if -2 in matching_cases['징역(개월)'].values:
        highest_sentence = "사형"
    elif -1 in matching_cases['징역(개월)'].values:
        highest_sentence = "무기징역"
    else:
        highest_sentence_years = matching_cases['징역(년)'].max()
        highest_sentence = f"{int(highest_sentence_years)}년"

    bins = np.arange(0, matching_cases['징역(년)'].max() + 1, 1)
    hist, bin_edges = np.histogram(matching_cases['징역(년)'], bins=bins)

    # 가장 높은 빈도의 년도 구간 찾기
    max_bin_index = np.argmax(hist)
    max_bin_start = bin_edges[max_bin_index]
    max_bin_end = bin_edges[max_bin_index + 1]
    max_bin_count = hist[max_bin_index]

    max_bin_percentage = int((max_bin_count / total_count) * 100)
    result_string = f"{int(max_bin_start)}~{int(max_bin_end)}년"

elif highest_percentage == '집행유예':
    highest_probation_months = matching_cases['집행유예(개월)'].max()
    highest_sentence = f"{int(highest_probation_months)}개월"

    bins = np.arange(0, matching_cases['집행유예(개월)'].max() + 1, 1)
    hist, bin_edges = np.histogram(matching_cases['집행유예(개월)'], bins=bins)

    # 가장 높은 빈도의 월 구간 찾기
    max_bin_index = np.argmax(hist)
    max_bin_start = bin_edges[max_bin_index]
    max_bin_end = bin_edges[max_bin_index + 1]
    max_bin_count = hist[max_bin_index]

    max_bin_percentage = int((max_bin_count / total_count) * 100)
    result_string = f"{int(max_bin_start)}~{int(max_bin_end)}개월"


else:  # 'fine'
    highest_fine = matching_cases['벌금'].max()
    highest_sentence = f"{highest_fine}원"

    bins = np.arange(0, matching_cases['벌금'].max() + 5000000, 5000000)
    hist, bin_edges = np.histogram(matching_cases['벌금'], bins=bins)

    # 가장 높은 빈도의 벌금 구간 찾기
    max_bin_index = np.argmax(hist)
    max_bin_start = bin_edges[max_bin_index]
    max_bin_end = bin_edges[max_bin_index + 1]
    max_bin_count = hist[max_bin_index]

    max_bin_percentage = int((max_bin_count / total_count) * 100)
    result_string = f"{int(max_bin_start)}~{int(max_bin_end)}원"
if highest_sentence=="0년":
  highest_sentence=str(max(matching_cases['징역(개월)']))+"개월"

# 결과 출력
print("전체 개수",total_count)
print("징역 개수:",jail_count)
print("집행유예 개수:",probation_count)
print("벌금 개수:",fine_count)
print("가장 높은 비율의 형량 유형:", highest_percentage)
print("최고 형량:", highest_sentence)
print("가장 높은 빈도의 구간:", result_string)
print("해당 구간의 비율:", max_bin_percentage)
# Out:
# 전체 개수 21
# 징역 개수: 2
# 집행유예 개수: 2
# 벌금 개수: 17
# 가장 높은 비율의 형량 유형: 벌금
# 최고 형량: 63990000.0원
# 가장 높은 빈도의 구간: 0~10000000원
# 해당 구간의 비율: 80

# %%
drilldown_data = {
    'breadcrumbs': {
        'position': {
            'align': 'right'
        }
    },
    'series': []
}

# 징역(년) 데이터 생성
jail_bins = np.arange(0, matching_cases['징역(년)'].max() + 1, 1)  # 년 단위로 그룹화
jail_hist, jail_bin_edges = np.histogram(matching_cases[matching_cases['징역'] == 1]['징역(년)'], bins=jail_bins)
drilldown_data['series'].append({
    'name': '징역(년)',
    'id': '징역(년)',
    'data': [[f"{int(jail_bin_edges[i])}~{int(jail_bin_edges[i + 1])}년", int(jail_hist[i])] for i in range(len(jail_hist))]
})

# 집행유예(년) 데이터 생성
probation_bins = np.arange(0, matching_cases['집행유예(개월)'].max() / 12 + 1, 1)  # 년 단위로 그룹화
probation_hist, probation_bin_edges = np.histogram(matching_cases[matching_cases['집행유예'] == 1]['집행유예(개월)'] / 12, bins=probation_bins)
drilldown_data['series'].append({
    'name': '집행유예(년)',
    'id': '집행유예(년)',
    'data': [[f"{int(probation_bin_edges[i])}~{int(probation_bin_edges[i + 1])}년", int(probation_hist[i])] for i in range(len(probation_hist))]
})

# 벌금 데이터 생성
fine_bins = np.arange(0, matching_cases['벌금'].max() + 500000, 500000)
fine_hist, fine_bin_edges = np.histogram(matching_cases[matching_cases['벌금1'] == 1]['벌금'], bins=fine_bins)
drilldown_data['series'].append({
    'name': '벌금',
    'id': '벌금',
    'data': [[f"{int(fine_bin_edges[i])}~{int(fine_bin_edges[i + 1])}원", int(fine_hist[i])] for i in range(len(fine_hist))]
})


# 결과 출력
drilldown_data
# Out:
# {'breadcrumbs': {'position': {'align': 'right'}},
#  'series': [{'name': '징역(년)',
#    'id': '징역(년)',
#    'data': [['0~1년', 2],
#     ['1~2년', 0],
#     ['2~3년', 2],
#     ['3~4년', 4],
#     ['4~5년', 1],
#     ['5~6년', 1],
#     ['6~7년', 0],
#     ['7~8년', 0],
#     ['8~9년', 0],
#     ['9~10년', 0],
#     ['10~11년', 0],
#     ['11~12년', 0],
#     ['12~13년', 0],
#     ['13~14년', 0],
#     ['14~15년', 1]]},
#   {'name': '집행유예(년)',
#    'id': '집행유예(년)',
#    'data': [['0~1년', 0], ['1~2년', 1], ['2~3년', 0], ['3~4년', 0], ['4~5년', 1]]},
#   {'name': '벌금', 'id': '벌금', 'data': []}]}

# %%
jail_hist
# Out:
# array([8])

# %%
import zipfile
with zipfile.ZipFile('news-analysis-key-pair.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
import subprocess

# SSH 키 파일 권한 설정
chmod_command = ['chmod', '400', './news-analysis-key-pair.pem']
subprocess.run(chmod_command)

# 결과 확인
ls_command = ['ls', '-l', './news-analysis-key-pair.pem']
result = subprocess.run(ls_command, capture_output=True, text=True)
print(result.stdout)

# 압축 파일 전송
scp_command = [
    'scp',
    '-o', 'StrictHostKeyChecking=no',
    '-i', './news-analysis-key-pair.pem',
    'filtered_dataset_df.tar.gz',
    'ubuntu@15.164.119.80:/home/ubuntu/'
]

result = subprocess.run(scp_command, capture_output=True, text=True)

ssh_key_path = './news-analysis-key-pair.pem'  # SSH 키 파일 경로
ec2_user = 'ubuntu'
ec2_host = '15.164.119.80'
remote_path = '/home/ubuntu/'

scp_command = [
    'scp',
    '-i', ssh_key_path,
    tar_filename,
    f'{ec2_user}@{ec2_host}:{remote_path}'
]

# 전송 시도 및 오류 출력
result = subprocess.run(scp_command, capture_output=True, text=True)
if result.returncode != 0:
    print("Error:", result.stderr)
else:
    print("File transferred successfully")
# Out:
# -r-------- 1 root root 1674 Jun 11 10:37 ./news-analysis-key-pair.pem
#
# File transferred successfully
